# %% [markdown]
# # Complete API Testing Flow - Ziya LRG API
#
# This notebook provides a comprehensive testing flow for all API endpoints in the Ziya LRG platform.
#
# ## API Categories Covered:
# 1. **Health & Meta** - Server health checks and endpoint discovery
# 2. **Content Management** - Reading, Listening, Grammar, Writing, Speaking
# 3. **Session Management** - Starting and submitting test sessions
# 4. **Listening Evaluation** - Specialized listening test sessions
# 5. **XP & Streaks** - Experience points and streak tracking
# 6. **Skill Mastery** - Skill progress and competency tracking
# 7. **Dashboard** - Analytics and user progress
# 8. **Unified Analytics** - Combined LRG, Writing, Speaking data
#
# ## Test Flow Strategy:
# - Each section builds upon previous sections
# - Proper setup and cleanup
# - Error handling to prevent test failures
# - Visual output for easy verification

# %% [markdown]
# ## 1. Setup & Configuration

# %%
import requests
import json
from datetime import datetime, timedelta, timezone
from uuid import uuid4
import time
from typing import Optional, Dict, Any
import jwt
# API Configuration
BASE_URL = "https://zia-lrg-166647007319.europe-west1.run.app/api/v1"
ROOT_URL = "https://zia-lrg-166647007319.europe-west1.run.app"

# Test User Configuration
TEST_USER_ID = "123e4567-e89b-12d3-a456-426614174000"  # Replace with actual user UUID
AUTH_TOKEN = "test-token-12345"  # Replace with actual auth token
TEST_USER_ID = str(uuid4())  # Replace with actual user_id if needed

# Create a JWT token for authentication (matches what the API expects)
def create_test_token(user_id: str) -> str:
    """Create a test JWT token with user_id in 'sub' claim"""
    payload = {
        "sub": user_id,  # User ID
        "iat": datetime.now(timezone.utc),
        "exp": datetime.now(timezone.utc) + timedelta(hours=24)
    }
    # Note: API uses verify_signature=False, so any token with correct structure works
    token = jwt.encode(payload, "test-secret", algorithm="HS256")
    return token

# Generate token
AUTH_TOKEN = create_test_token(TEST_USER_ID)

# Headers for authenticated requests
AUTH_HEADERS = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "Content-Type": "application/json"
}
# Request Headers
HEADERS = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {AUTH_TOKEN}"
}

# Color codes for output
class Colors:
    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    BLUE = '\033[94m'
    RESET = '\033[0m'

# Helper function to print formatted responses
def print_response(title: str, response: requests.Response, show_body: bool = True):
    """Print formatted API response"""
    status_color = Colors.GREEN if response.status_code < 300 else Colors.YELLOW if response.status_code < 400 else Colors.RED
    
    print(f"\n{Colors.BLUE}{'='*80}{Colors.RESET}")
    print(f"{Colors.BLUE}{title}{Colors.RESET}")
    print(f"{status_color}Status: {response.status_code}{Colors.RESET}")
    
    if show_body:
        try:
            print(f"\n{Colors.YELLOW}Response:{Colors.RESET}")
            print(json.dumps(response.json(), indent=2))
        except:
            print(f"Response: {response.text}")
    
    print(f"{Colors.BLUE}{'='*80}{Colors.RESET}")
    return response

# Helper function for safe API calls
def safe_api_call(method: str, url: str, **kwargs) -> Optional[requests.Response]:
    """Make API call with error handling"""
    try:
        response = requests.request(method, url, **kwargs)
        return response
    except Exception as e:
        print(f"{Colors.RED}Error: {e}{Colors.RESET}")
        return None

# Storage for test data
test_data = {
    'reading_id': None,
    'listening_id': None,
    'grammar_id': None,
    'writing_id': None,
    'speaking_id': None,
    'session_id': None,
    'listening_session_id': None
}

print(f"{Colors.GREEN}Setup Complete!{Colors.RESET}")
print(f"Base URL: {BASE_URL}")
print(f"Test User ID: {TEST_USER_ID}")
# Out:
# Setup Complete!
# Base URL: https://zia-lrg-166647007319.europe-west1.run.app/api/v1
# Test User ID: 87f27677-c00e-43d8-abc1-9ee77ef508e5

# %% [markdown]
# ## 2. Health & Meta Endpoints

# %%
# Test root endpoint
response = safe_api_call("GET", f"{ROOT_URL}/")
if response:
    print_response("Root Endpoint - Health Check", response)

# Test health endpoint
response = safe_api_call("GET", f"{ROOT_URL}/health")
if response:
    print_response("Health Check - Detailed", response)

# List all API endpoints
response = safe_api_call("GET", f"{BASE_URL}/meta/endpoints")
if response:
    print_response("Meta - List All Endpoints", response, show_body=False)
    if response.status_code == 200:
        data = response.json()
        print(f"\n{Colors.GREEN}Total Endpoints: {data.get('count', 0)}{Colors.RESET}")
        print(f"\nEndpoint Categories:")
        tags = {}
        for route in data.get('routes', []):
            for tag in route.get('tags', ['Uncategorized']):
                tags[tag] = tags.get(tag, 0) + 1
        for tag, count in sorted(tags.items()):
            print(f"  {tag}: {count} endpoints")
# Out:
# ================================================================================
# Root Endpoint - Health Check
# Status: 200
#
# Response:
# {
#   "status": "healthy",
#   "service": "Ziya LRG API",
#   "version": "1.0.0"
# }
# ================================================================================
#
# ================================================================================
# Health Check - Detailed
# Status: 200
#
# Response:
# {
#   "status": "healthy",
#   "database": "connected",
#   "storage": "ready"
# }
# ================================================================================
#
# ================================================================================
# Meta - List All Endpoints
# Status: 200
# ================================================================================
#
# Total Endpoints: 56
#
# Endpoint Categories:
#   Content: 25 endpoints
#   Dashboard: 3 endpoints
#   Listening Evaluation: 6 endpoints
#   Meta: 1 endpoints
#   Sessions: 4 endpoints
#   Skill Mastery: 4 endpoints
#   Unified Analytics: 7 endpoints
#   XP & Streaks: 6 endpoints

# %% [markdown]
# ## 3. Content Management - Reading

# %%
# Create Reading Content
reading_data = {
    "day_code": "day1",
    "difficulty_level": "beginner",
    "title": "Introduction to Python",
    "passage": "Python is a high-level, interpreted programming language known for its simplicity and readability.",
    "questions": [
        {
            "question_text": "What type of language is Python?",
            "question_type": "multiple_choice",
            "options": ["High-level", "Low-level", "Assembly", "Machine"],
            "correct_answer": "High-level",
            "skill_tag": "comprehension"
        },
        {
            "question_text": "Python is known for its _____ and _____.",
            "question_type": "fill_blank",
            "correct_answer": "simplicity, readability",
            "skill_tag": "vocabulary"
        }
    ]
}

response = safe_api_call("POST", f"{BASE_URL}/reading", headers=HEADERS, json=reading_data)
if response:
    print_response("Create Reading Content", response)
    if response.status_code == 201:
        test_data['reading_id'] = response.json().get('reading_id')
        print(f"{Colors.GREEN}Reading ID saved: {test_data['reading_id']}{Colors.RESET}")

# Get Reading by Day
response = safe_api_call("GET", f"{BASE_URL}/reading/day/day1", headers=HEADERS)
if response:
    print_response("Get Reading by Day (day1)", response)

# Get Reading by ID (if we have one)
if test_data['reading_id']:
    response = safe_api_call("GET", f"{BASE_URL}/reading/{test_data['reading_id']}", headers=HEADERS)
    if response:
        print_response(f"Get Reading by ID ({test_data['reading_id']})", response)

# Update Reading (if we have one)
if test_data['reading_id']:
    update_data = reading_data.copy()
    update_data['title'] = "Introduction to Python - Updated"
    response = safe_api_call("PUT", f"{BASE_URL}/reading/{test_data['reading_id']}", headers=HEADERS, json=update_data)
    if response:
        print_response("Update Reading Content", response)
# Out:
# ================================================================================
# Get Reading by Day (day1)
# Status: 200
#
# Response:
# {
#   "day_code": "day1",
#   "readings": [
#     {
#       "reading_id": "e95b3402-e8dc-422a-8ff1-f33247477224",
#       "day_code": "day1",
#       "title": " The Missing Context",
#       "passage": "Story: Jian, a software developer in Singapore, sent a terse, one-line email to his team in Manila: \"Database update needed urgently.\" He assumed the technical context was obvious. However, his team was working on a different priority and interpreted \"urgently\" as needing to drop everything immediately, causing unnecessary panic. The project manager intervened, advising Jian: \"When communicating across cultures and teams, clarity trumps brevity. Always include the 'why' and the 'impact'.\" Jian learned that the effort saved by typing less was offset by the time lost to confusion and misinterpretation.\n\nMoral: Clarity in communication, especially across diverse teams, requires context and explicit explanation of the urgency and impact.\n",
#       "questions": [
#         {
#           "id": "q1760165757270",
#           "q": "What was Jian\u2019s job?",
#           "options": {
#             "a": "A project manager",
#             "b": "A salesperson",
#             "c": "A software developer",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Direct Wording/Context: The story starts: \"Jian, a software developer in Singapore, sent a terse, one-line email...\"",
#           "topic": null
#         },
#         {
#           "id": "q1760165791037",
#           "q": "What was the problem with Jian's email?",
#           "options": {
#             "a": "It was too long",
#             "b": "It was terse (brief and abrupt)",
#             "c": "It was too polite",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: Jian sent a terse, one-line email.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1760165791461",
#           "q": "What did Jian assume about his team?",
#           "options": {
#             "a": "They were lazy",
#             "b": "They were busy",
#             "c": "The technical context was obvious",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Direct Wording/Context: He assumed the technical context was obvious.",
#           "topic": null
#         },
#         {
#           "id": "q1760165791694",
#           "q": "What was the result of the email for the Manila team?",
#           "options": {
#             "a": "Unnecessary panic and confusion",
#             "b": "A big bonus",
#             "c": "A new project",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: The email caused unnecessary panic and misinterpretation, leading to confusion.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1760165791886",
#           "q": "What quality did the project manager say \"trumps brevity\"?",
#           "options": {
#             "a": "Speed",
#             "b": "Clarity",
#             "c": "Politeness",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: The project manager advised: \"Clarity trumps brevity.\"",
#           "topic": null
#         },
#         {
#           "id": "q1760165792070",
#           "q": "What two things did Jian learn he must include in his communication?",
#           "options": {
#             "a": "The time and date",
#             "b": "The 'why' and the 'impact'",
#             "c": "The cost and the name",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: The project manager said: \"Always include the 'why' and the 'impact'.\"\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1760165792245",
#           "q": " The word \"terse\" means:",
#           "options": {
#             "a": "Very lengthy",
#             "b": "Brief and slightly rude",
#             "c": "Very confusing",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Vocabulary/Context: \"Terse\" means brief, often to the point of seeming rude or short (abrupt).\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1760165792414",
#           "q": " What does \"misinterpretation\" mean?",
#           "options": {
#             "a": "Understanding something incorrectly",
#             "b": "Agreeing easily",
#             "c": "Understanding something quickly",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Vocabulary/Context: \"Misinterpretation\" means to interpret or understand something wrongly (understanding something incorrectly).",
#           "topic": null
#         },
#         {
#           "id": "q1760165792598",
#           "q": "What did Jian save by typing less?",
#           "options": {
#             "a": "The project",
#             "b": "The effort/time",
#             "c": "The communication",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: Jian learned that the effort saved by typing less was offset by the time lost. Typing less saves effort/time.",
#           "topic": null
#         },
#         {
#           "id": "q1760165797054",
#           "q": " The story emphasizes that good communication needs:",
#           "options": {
#             "a": "Quick typing speed",
#             "b": "Explicit context and rationale",
#             "c": "Short emails",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Context/Moral: The Moral states that clarity requires context and explicit explanation of the urgency (rationale) and impact.\n\n",
#           "topic": null
#         }
#       ],
#       "difficulty_level": "advanced",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Iluzia Lab",
#         "uploaded_time": "2025-10-11T07:12:03.934000+00:00"
#       },
#       "created_at": "2025-10-11T07:12:07.366114Z"
#     },
#     {
#       "reading_id": "536c930e-425b-4adf-90c8-54b6f0e59994",
#       "day_code": "day1",
#       "title": "The Tenacity of Abraham Lincoln",
#       "passage": "Story Title: The Tenacity of Abraham Lincoln Story Text: Abraham Lincoln, the 16th U.S. President, is celebrated as a symbol of perseverance, even though his early career was plagued by failure. Before his presidency, he ran for state legislature and lost. He tried starting a business which quickly failed, leaving him heavily in debt. His political ambition suffered repeated setbacks, including multiple failed bids for Congress and the Senate. Despite these crushing disappointments, Lincoln refused to quit. He often remarked that these losses were simply lessons in what not to do. This enduring spirit and his commitment to his principles eventually propelled him to the highest office during the nation\u2019s greatest crisis. His story truly exemplifies how resilience can ultimately overcome a long string of initial defeats.\n\nConclusion/Moral: Do not view setbacks as final stops, but as necessary detours on the path to lasting success.\n",
#       "questions": [
#         {
#           "id": "q1759819594741",
#           "q": "What is Abraham Lincoln celebrated as a symbol of?",
#           "options": {
#             "a": "Easy success",
#             "b": " Perseverance (not giving up)",
#             "c": " Financial debt",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: Lincoln is celebrated as a symbol of perseverance (meaning, not giving up), even though his early career was plagued by failure.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759819727516",
#           "q": "What does the phrase \"plagued by failure\" mean?",
#           "options": {
#             "a": "That he avoided failure",
#             "b": " That he quickly succeeded",
#             "c": "That he suffered from many problems or failures",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Vocabulary/Context: To be \"plagued by failure\" means to be repeatedly troubled or suffered from many problems or failures.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759819911956",
#           "q": "What happened to the business Lincoln tried to start? ",
#           "options": {
#             "a": "It quickly failed, leaving him in debt",
#             "b": "It became very profitable",
#             "c": " It was very successful at first",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: He tried starting a business which quickly failed, leaving him heavily in debt.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759819912484",
#           "q": "What kind of political attempts did he fail at multiple times? ",
#           "options": {
#             "a": " Bids for Congress and the Senate ",
#             "b": " Running for President",
#             "c": "Starting a new political party",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: His political ambition suffered repeated setbacks, including multiple failed bids for Congress and the Senate.",
#           "topic": null
#         },
#         {
#           "id": "q1759819913052",
#           "q": "What did Lincoln often remark about his losses? ",
#           "options": {
#             "a": "That they were crushing setbacks",
#             "b": "That they were simply lessons in what not to do",
#             "c": "That he should quit politics.",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: Lincoln often remarked that these losses were simply lessons in what not to do.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759819913364",
#           "q": "What eventually propelled him to the highest office?",
#           "options": {
#             "a": "His enduring spirit and commitment to principles ",
#             "b": "His financial debt",
#             "c": " A successful business",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: This enduring spirit and his commitment to his principles eventually propelled him to the highest office.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759820110996",
#           "q": "What crisis did he lead the nation through? ",
#           "options": {
#             "a": "A public debate",
#             "b": "A financial crisis",
#             "c": "The nation\u2019s greatest crisis",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Direct Wording/Context: He was propelled to the highest office during the nation\u2019s greatest crisis.",
#           "topic": null
#         },
#         {
#           "id": "q1759820111444",
#           "q": "The word \"propelled\" means: ",
#           "options": {
#             "a": " Stopped completely",
#             "b": "Driven or forced forward (pushed)",
#             "c": " Caused him to fall",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Vocabulary/Context/Tense: The verb \"propelled\" (past tense) means to drive, push, or force something in a particular direction",
#           "topic": null
#         },
#         {
#           "id": "q1759820111804",
#           "q": "What does the story exemplify about resilience?",
#           "options": {
#             "a": " How it can overcome a long string of initial defeats",
#             "b": " That it prevents all setbacks",
#             "c": " That it causes financial trouble",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: His story truly exemplifies how resilience can ultimately overcome a long string of initial defeats.\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759820112124",
#           "q": "What should setbacks be viewed as?",
#           "options": {
#             "a": "Necessary detours on the path to success",
#             "b": "Final stops",
#             "c": "Crushing disappointments",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Moral: The Moral advises: Do not view setbacks as final stops, but as necessary detours on the path to lasting success.\n\n",
#           "topic": null
#         }
#       ],
#       "difficulty_level": "intermediate",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Iluzia Lab",
#         "uploaded_time": "2025-10-13T09:09:15.545Z"
#       },
#       "created_at": "2025-10-07T06:50:22.384570Z"
#     },
#     {
#       "reading_id": "9ca03872-4626-4965-a9bc-41ee460b5fa0",
#       "day_code": "day1",
#       "title": "The Magic of J.K. Rowling",
#       "passage": "\nStory Title: The Magic of J.K. Rowling: J.K. Rowling is the famous writer of the Harry Potter books. Before she became famous, life was very hard for her. She was a single mother and often did not have much money. She wrote the first Harry Potter book in small cafes, sometimes using old, used napkins to write her ideas. Many publishing companies rejected her book. Twelve different publishers said \"No\" to her story. Finally, one small company, Bloomsbury, agreed to publish it. They only printed a very small number of copies at first. Rowling never stopped believing in her magical world and her writing. Today, the Harry Potter books have sold more than 500 million copies around the world. Her story shows that hard work and belief can turn a difficult life into a famous success.\n\nConclusion/Moral: Never give up on your ideas, even when many people say no.\n",
#       "questions": [
#         {
#           "id": "q1759818492595",
#           "q": "What is J.K. Rowling famous for writing?",
#           "options": {
#             "a": "The Lord of the Rings",
#             "b": "Famous poems",
#             "c": "The Harry Potter books ",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Direct Wording/Context: The story starts: \"J.K. Rowling is the famous writer of the Harry Potter books.\"",
#           "topic": null
#         },
#         {
#           "id": "q1759818918307",
#           "q": "What was her job before she became famous?",
#           "options": {
#             "a": " A doctor",
#             "b": " She was a single mother and struggled with money",
#             "c": " A publisher",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: The text states, \"She was a single mother and often did not have much money.\"\n\n",
#           "topic": null
#         },
#         {
#           "id": "q1759821011906",
#           "q": "Where did she sometimes write her ideas?",
#           "options": {
#             "a": " In a big office",
#             "b": "In small cafes, on napkins ",
#             "c": " At her publisher's desk",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: She wrote the first book in small cafes, sometimes using old, used napkins to write her ideas.",
#           "topic": null
#         },
#         {
#           "id": "q1759821015643",
#           "q": "How many publishing companies rejected her book?",
#           "options": {
#             "a": "Twelve different companies ",
#             "b": " Two companies",
#             "c": " One hundred companies",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: The text states: \"Twelve different publishers said \"No\" to her story.\"",
#           "topic": null
#         },
#         {
#           "id": "q1759821016330",
#           "q": "What was the name of the company that finally published the book?",
#           "options": {
#             "a": "Bloomsbury",
#             "b": " Penguin Books",
#             "c": "The Magic Company",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Direct Wording/Context: The text says, \"Finally, one small company, Bloomsbury, agreed to publish it.\"",
#           "topic": null
#         },
#         {
#           "id": "q1759821016858",
#           "q": "How many copies did the publisher print at first?",
#           "options": {
#             "a": "500 million copies",
#             "b": " A large number",
#             "c": "A very small number",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Direct Wording/Context: The text says, \"They only printed a very small number of copies at first.\"",
#           "topic": null
#         },
#         {
#           "id": "q1759821017386",
#           "q": "What did Rowling never stop believing in?",
#           "options": {
#             "a": "Becoming rich",
#             "b": "Her magical world and her writing",
#             "c": " Her publishers",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: The text states, \"Rowling never stopped believing in her magical world and her writing.\"",
#           "topic": null
#         },
#         {
#           "id": "q1759821017930",
#           "q": "How many copies have the Harry Potter books sold today?",
#           "options": {
#             "a": "Only a small number",
#             "b": " 12 million copies",
#             "c": " More than 500 million copies",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "Direct Wording/Context: The text gives the specific number: \"...have sold more than 500 million copies around the world.\"",
#           "topic": null
#         },
#         {
#           "id": "q1759821018474",
#           "q": "What kind of life did her hard work turn into success?",
#           "options": {
#             "a": " A writing life",
#             "b": "A difficult life",
#             "c": " An easy life",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Direct Wording/Context: Her story shows that hard work and belief can turn a difficult life into a famous success.",
#           "topic": null
#         },
#         {
#           "id": "q1759821018986",
#           "q": "What is the main idea of the story?",
#           "options": {
#             "a": " Perseverance and belief are important for success",
#             "b": " It is easy to become a famous writer",
#             "c": "Writing on napkins is a good habit",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Context/Theme/Moral: The story details her persistence (12 rejections) and her belief in her work. The Moral is: \"Never give up,\" which means Perseverance.",
#           "topic": null
#         }
#       ],
#       "difficulty_level": "beginner",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Illuzia Lab",
#         "uploaded_time": "2025-10-07T12:43:34.323Z"
#       },
#       "created_at": "2025-10-07T06:30:17.429752Z"
#     }
#   ],
#   "count": 3
# }
# ================================================================================

# %% [markdown]
# ## 4. Content Management - Grammar

# %%
# Create Grammar Content
grammar_data = {
    "day_code": "day1",
    "difficulty_level": "beginner",
    "topic": "Present Simple Tense",
    "explanation": "The present simple tense is used to describe habits, unchanging situations, general truths, and fixed arrangements.",
    "examples": [
        "I work in an office.",
        "She plays tennis every weekend.",
        "The sun rises in the east."
    ],
    "questions": [
        {
            "question_text": "Choose the correct form: He _____ to work every day.",
            "question_type": "multiple_choice",
            "options": ["go", "goes", "going", "went"],
            "correct_answer": "goes",
            "skill_tag": "verb_conjugation"
        },
        {
            "question_text": "They _____ (play) football on Saturdays.",
            "question_type": "fill_blank",
            "correct_answer": "play",
            "skill_tag": "verb_conjugation"
        }
    ]
}

response = safe_api_call("POST", f"{BASE_URL}/grammar", headers=HEADERS, json=grammar_data)
if response:
    print_response("Create Grammar Content", response)
    if response.status_code == 201:
        test_data['grammar_id'] = response.json().get('grammar_id')
        print(f"{Colors.GREEN}Grammar ID saved: {test_data['grammar_id']}{Colors.RESET}")

# Get Grammar by Day
response = safe_api_call("GET", f"{BASE_URL}/grammar/day/day1", headers=HEADERS)
if response:
    print_response("Get Grammar by Day (day1)", response)

# Get Grammar by ID
if test_data['grammar_id']:
    response = safe_api_call("GET", f"{BASE_URL}/grammar/{test_data['grammar_id']}", headers=HEADERS)
    if response:
        print_response(f"Get Grammar by ID ({test_data['grammar_id']})", response)
# Out:
# ================================================================================
# Get Grammar by Day (day1)
# Status: 200
#
# Response:
# {
#   "day_code": "day1",
#   "grammar_sets": [
#     {
#       "grammar_id": "138ef5a2-d86c-40a4-ba3f-cd0bb3ab8eec",
#       "day_code": "day1",
#       "title": "ADVANCED GRAMMAR AND NUANCED USAGE",
#       "tasks": [
#         {
#           "id": "g1760003940771",
#           "type": "mcq",
#           "prompt": "Had I known you were coming, I ___________ a meal for you.",
#           "options": {
#             "a": "would prepare",
#             "b": "will prepare",
#             "c": "would have prepared",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "",
#           "topic": ""
#         },
#         {
#           "id": "g1760003942211",
#           "type": "mcq",
#           "prompt": "She _________ to the store, but I'm not sure.",
#           "options": {
#             "a": "might have gone",
#             "b": "might go",
#             "c": "must go ",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "",
#           "topic": ""
#         },
#         {
#           "id": "g1760003942691",
#           "type": "mcq",
#           "prompt": "The report _________ by the committee when the error was found.",
#           "options": {
#             "a": "was reviewed",
#             "b": "was being reviewed",
#             "c": "had been reviewed",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "",
#           "topic": ""
#         },
#         {
#           "id": "g1760003943115",
#           "type": "mcq",
#           "prompt": "He _________ all night, as he looks exhausted.",
#           "options": {
#             "a": "must study",
#             "b": "must have studied",
#             "c": "must have been studying",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "",
#           "topic": ""
#         },
#         {
#           "id": "g1760003943515",
#           "type": "mcq",
#           "prompt": "If she ________ the lottery, she would travel the world.",
#           "options": {
#             "a": "wins",
#             "b": "were to win",
#             "c": "will win",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "",
#           "topic": ""
#         },
#         {
#           "id": "g1760441434857",
#           "type": "mcq",
#           "prompt": "By this time next year, the company ______ for fifty years. ",
#           "options": {
#             "a": "will have been operating",
#             "b": "will operate",
#             "c": "will be operating",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "This shows an action that continues up to a future point, and will have been operating is the future perfect continuous indicating duration until a future moment.",
#           "topic": ""
#         },
#         {
#           "id": "g1760441435441",
#           "type": "mcq",
#           "prompt": "It's high time you ______ taking your studies seriously.  ",
#           "options": {
#             "a": "start",
#             "b": "started",
#             "c": "are starting",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "This indicates an action that should already have begun, and started is the subjunctive past used after \u201cIt\u2019s high time.\u201d",
#           "topic": ""
#         },
#         {
#           "id": "g1760441435857",
#           "type": "mcq",
#           "prompt": "_______ the project, he took a long vacation.   ",
#           "options": {
#             "a": "After finishing",
#             "b": "To finish",
#             "c": "Having finished",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "This shows that one action was completed before another began, and Having finished is a perfect participle indicating prior completion.",
#           "topic": ""
#         },
#         {
#           "id": "g1760441436185",
#           "type": "mcq",
#           "prompt": "I ______ I saw him at the library yesterday. ",
#           "options": {
#             "a": "could have sworn",
#             "b": "can swear ",
#             "c": "could swear",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "This expresses strong past belief or certainty, and could have sworn is the modal perfect indicating a strong assumption about a past event.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760441436649",
#           "type": "mcq",
#           "prompt": "The old house _______ haunted for centuries.  ",
#           "options": {
#             "a": "was said to be",
#             "b": "is said to be",
#             "c": "is said to have been",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "This shows present belief about a past situation, and is said to have been is the passive perfect infinitive indicating reported past action.\n",
#           "topic": ""
#         }
#       ],
#       "difficulty_level": "advanced",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Iluzia Lab",
#         "uploaded_time": "2025-10-14T11:37:23.664Z"
#       },
#       "created_at": "2025-10-09T10:04:17.419499Z"
#     },
#     {
#       "grammar_id": "2e022dbc-c3d6-4af1-b432-2fcc5a509cd8",
#       "day_code": "day1",
#       "title": "COMPLEX TENSES AND VERB FORMS",
#       "tasks": [
#         {
#           "id": "g1760000968998",
#           "type": "mcq",
#           "prompt": "They _________ for two hours before the bus finally arrived.",
#           "options": {
#             "a": "waited",
#             "b": "were waiting",
#             "c": "ave been waiting",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "\u201cThe action started in the past and continued up to a certain point.\u201d Present perfect continuous \u201chave been waiting\u201d shows ongoing duration.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760001125006",
#           "type": "mcq",
#           "prompt": "She ______ her work by the time the guests arrived",
#           "options": {
#             "a": "had finished ",
#             "b": "finished ",
#             "c": "finishes   ",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "\u201cThe action was completed before another past action.\u201d Past perfect tense \u201chad finished\u201d shows sequence of events.",
#           "topic": ""
#         },
#         {
#           "id": "g1760001125550",
#           "type": "mcq",
#           "prompt": "I __________on my presentation all day tomorrow.",
#           "options": {
#             "a": "work",
#             "b": "will be working",
#             "c": "have worked",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "\u201cThe action will be ongoing in the future.\u201d Future continuous tense \u201cwill be working\u201d indicates continuous activity tomorrow.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760001125982",
#           "type": "mcq",
#           "prompt": "By next month, she _________ her degree.",
#           "options": {
#             "a": "completes",
#             "b": "will complete",
#             "c": "will have completed",
#             "d": ""
#           },
#           "answer": "",
#           "explanation": "\u201cThe action will be finished before a future time.\u201d Future perfect tense \u201cwill have completed\u201d shows completion by a specific time.",
#           "topic": ""
#         },
#         {
#           "id": "g1760002289885",
#           "type": "mcq",
#           "prompt": "He __________ to play the guitar for three months now.",
#           "options": {
#             "a": "learned",
#             "b": "has been learning",
#             "c": " is learning ",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "\u201cThe action started in the past and continues now.\u201d Present perfect continuous \u201chas been learning\u201d shows ongoing learning duration.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760090273616",
#           "type": "mcq",
#           "prompt": "They _______ when we got to the party. ",
#           "options": {
#             "a": "were leaving",
#             "b": "left ",
#             "c": "had already left ",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "\u201cThe action was completed before another past action.\u201d Past perfect \u201chad already left\u201d indicates sequence in the past.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760090275568",
#           "type": "mcq",
#           "prompt": "We ______ a meeting at this time tomorrow.  ",
#           "options": {
#             "a": " had",
#             "b": "will be having",
#             "c": " will have ",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "",
#           "topic": ""
#         },
#         {
#           "id": "g1760090278216",
#           "type": "mcq",
#           "prompt": "The company _______ its business into new markets. ",
#           "options": {
#             "a": " has been expanding",
#             "b": "expands",
#             "c": "expanded",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "\u201cThe action started in the past and continues now.\u201d Present perfect continuous \u201chas been expanding\u201d shows ongoing expansion.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760090278696",
#           "type": "mcq",
#           "prompt": "I ______ her since high school.   ",
#           "options": {
#             "a": "did not see",
#             "b": " had not seen ",
#             "c": " have not seen",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "\u201cThe action was completed in the past before another event.\u201d Past perfect \u201chad not seen\u201d expresses prior experience.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1760090279432",
#           "type": "mcq",
#           "prompt": "By the end of the year, I _______ fifty books. ",
#           "options": {
#             "a": "will have read",
#             "b": " have read ",
#             "c": " will be reading",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "\u201cThe action will be completed before a specific future time.\u201d Future perfect tense \u201cwill have read\u201d shows completed activity.\n",
#           "topic": ""
#         }
#       ],
#       "difficulty_level": "intermediate",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Iluzia Lab",
#         "uploaded_time": "2025-10-10T10:09:14.678Z"
#       },
#       "created_at": "2025-10-09T09:34:00.390388Z"
#     },
#     {
#       "grammar_id": "7c621d40-4b28-4aa5-9ccc-d6d3aee4e748",
#       "day_code": "day1",
#       "title": " SIMPLE TENSES",
#       "tasks": [
#         {
#           "id": "g1759835387930",
#           "type": "mcq",
#           "prompt": "I ______ to the store yesterday ",
#           "options": {
#             "a": " go",
#             "b": " went",
#             "c": "going",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Yesterday\u201d indicates the action happened in the past. The past tense of \u201cgo\u201d is \u201cwent,\u201d so it matches the time of action.",
#           "topic": ""
#         },
#         {
#           "id": "g1759835467954",
#           "type": "mcq",
#           "prompt": "She ______a beautiful song right now",
#           "options": {
#             "a": " sang ",
#             "b": "is singing",
#             "c": "will sing ",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "\u201cRight now\u201d shows the action is happening at this moment. Present continuous tense (\u201cis singing\u201d) is used for ongoing actions.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1759836446705",
#           "type": "mcq",
#           "prompt": "They  ______ their grandparents next week",
#           "options": {
#             "a": " visited",
#             "b": "visit",
#             "c": " will visit ",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "\u201cNext week\u201d points to a future action. Future tense is formed using \u201cwill + base verb,\u201d so \u201cwill visit\u201d is correct.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1759836518225",
#           "type": "mcq",
#           "prompt": "We ______ dinner together last night",
#           "options": {
#             "a": " eat",
#             "b": "ate",
#             "c": "will eat",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "\u201cLast night\u201d shows the past. The past tense of \u201ceat\u201d is \u201cate,\u201d which correctly expresses the completed action.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1759836570777",
#           "type": "mcq",
#           "prompt": "He______ every morning",
#           "options": {
#             "a": " run ",
#             "b": "ran",
#             "c": "runs",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "This is a habitual action (every morning). Simple present tense (\u201cruns\u201d) is used for routines and habits.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1759836611322",
#           "type": "mcq",
#           "prompt": "The cat______on the couch",
#           "options": {
#             "a": " slept",
#             "b": " is sleeping ",
#             "c": "sleeps",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "The action is happening right now. Present continuous (\u201cis sleeping\u201d) indicates ongoing activity.\n",
#           "topic": ""
#         },
#         {
#           "id": "g1759836653745",
#           "type": "mcq",
#           "prompt": "You ______ a book when I called",
#           "options": {
#             "a": "read",
#             "b": "were reading",
#             "c": " are reading",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Past continuous is used for an action in progress in the past, interrupted by another action (\u201cwhen I called\u201d)\n",
#           "topic": ""
#         },
#         {
#           "id": "g1759836654713",
#           "type": "mcq",
#           "prompt": "She ______ a cake for the party",
#           "options": {
#             "a": "baked",
#             "b": "bakes",
#             "c": "will bake",
#             "d": ""
#           },
#           "answer": "c",
#           "explanation": "The action is planned for the future. \u201cWill + base verb\u201d is the future tense.",
#           "topic": ""
#         },
#         {
#           "id": "g1759836655449",
#           "type": "mcq",
#           "prompt": "They______ soccer on weekends",
#           "options": {
#             "a": "play",
#             "b": "played",
#             "c": "are playing",
#             "d": ""
#           },
#           "answer": "a",
#           "explanation": "Simple present tense expresses habitual or regular activities.",
#           "topic": ""
#         },
#         {
#           "id": "g1759836656161",
#           "type": "mcq",
#           "prompt": "I ______ for my exam right now",
#           "options": {
#             "a": "study",
#             "b": "am studying",
#             "c": "studied",
#             "d": ""
#           },
#           "answer": "b",
#           "explanation": "Present continuous is used because the action is happening at this exact moment.",
#           "topic": ""
#         }
#       ],
#       "difficulty_level": "beginner",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Iluzia Lab",
#         "uploaded_time": "2025-10-10T07:13:33.568Z"
#       },
#       "created_at": "2025-10-07T11:35:21.355574Z"
#     }
#   ],
#   "count": 3
# }
# ================================================================================

# %% [markdown]
# ## 5. Content Management - Writing

# %%
# Create Writing Content
writing_data = {
    "day_code": "day1",
    "difficulty_level": "beginner",
    "prompt": "Write a short paragraph about your favorite hobby.",
    "topic": "Hobbies and Interests",
    "word_limit": 150,
    "rubric": {
        "grammar": "Check for proper sentence structure and tense usage",
        "vocabulary": "Use appropriate hobby-related vocabulary",
        "organization": "Clear introduction and conclusion",
        "creativity": "Original ideas and personal examples"
    },
    "sample_response": "My favorite hobby is reading. I enjoy reading because it allows me to explore new worlds and learn about different cultures. Every evening, I spend at least one hour reading books. This hobby helps me relax and expand my knowledge."
}

response = safe_api_call("POST", f"{BASE_URL}/writing", headers=HEADERS, json=writing_data)
if response:
    print_response("Create Writing Content", response)
    if response.status_code == 201:
        test_data['writing_id'] = response.json().get('writing_id')
        print(f"{Colors.GREEN}Writing ID saved: {test_data['writing_id']}{Colors.RESET}")

# Get Writing by Day
response = safe_api_call("GET", f"{BASE_URL}/writing/day/day1", headers=HEADERS)
if response:
    print_response("Get Writing by Day (day1)", response)

# Get Writing by ID
if test_data['writing_id']:
    response = safe_api_call("GET", f"{BASE_URL}/writing/{test_data['writing_id']}", headers=HEADERS)
    if response:
        print_response(f"Get Writing by ID ({test_data['writing_id']})", response)
# Out:
# ================================================================================
# Get Writing by Day (day1)
# Status: 200
#
# Response:
# {
#   "day_code": "day1",
#   "writings": [],
#   "count": 0
# }
# ================================================================================

# %% [markdown]
# ## 6. Content Management - Speaking

# %%
# Create Speaking Content
speaking_data = {
    "day_code": "day1",
    "difficulty_level": "beginner",
    "teaching_mode_code": "conversation",
    "topic": "Introducing Yourself",
    "prompt": "Introduce yourself to a new colleague. Include your name, job, and a hobby.",
    "context": "You are at a company meeting and meeting a new team member for the first time.",
    "duration_sec": 60,
    "evaluation_criteria": {
        "pronunciation": "Clear and understandable pronunciation",
        "fluency": "Smooth speech without excessive pauses",
        "vocabulary": "Appropriate workplace vocabulary",
        "grammar": "Correct use of present tense"
    },
    "sample_phrases": [
        "Hello, my name is...",
        "I work as a...",
        "In my free time, I enjoy...",
        "Nice to meet you!"
    ]
}

response = safe_api_call("POST", f"{BASE_URL}/speaking", headers=HEADERS, json=speaking_data)
if response:
    print_response("Create Speaking Content", response)
    if response.status_code == 201:
        test_data['speaking_id'] = response.json().get('speaking_id')
        print(f"{Colors.GREEN}Speaking ID saved: {test_data['speaking_id']}{Colors.RESET}")

# Get Speaking by Day
response = safe_api_call("GET", f"{BASE_URL}/speaking/day/day1", headers=HEADERS)
if response:
    print_response("Get Speaking by Day (day1)", response)

# Get Speaking by ID
if test_data['speaking_id']:
    response = safe_api_call("GET", f"{BASE_URL}/speaking/{test_data['speaking_id']}", headers=HEADERS)
    if response:
        print_response(f"Get Speaking by ID ({test_data['speaking_id']})", response)
# Out:
# ================================================================================
# Get Speaking by Day (day1)
# Status: 200
#
# Response:
# {
#   "day_code": "day1",
#   "topics": [
#     {
#       "speaking_id": "1deb3244-9d8b-48d1-9d73-b11453b757e8",
#       "day_code": "day1",
#       "teaching_mode_id": "c7c4631e-8e22-40e8-9ee9-c48936bc799b",
#       "teaching_mode_code": "grammar",
#       "title": "Advanced",
#       "topic": "Let\u2019s Talk About Your Favorite Sportsperson",
#       "context": " (Focus on their great achievements, how hard they practice, and what you learn from them.)\n",
#       "difficulty_level": "advanced",
#       "metadata": {
#         "uploaded_by": "admin@ailt.in",
#         "company_name": "AILT",
#         "uploaded_time": "2025-10-07T11:34:04.089000+00:00"
#       },
#       "created_at": "2025-10-07T11:34:03.736848Z"
#     },
#     {
#       "speaking_id": "179ed83a-83ea-4c95-a883-32bcb39859d9",
#       "day_code": "day1",
#       "teaching_mode_id": "c7c4631e-8e22-40e8-9ee9-c48936bc799b",
#       "teaching_mode_code": "grammar",
#       "title": "MEDIUM",
#       "topic": "The Importance of Reading Books ",
#       "context": "(Discuss why reading helps, what kind of books you like, and how you find time to read.)\n",
#       "difficulty_level": "intermediate",
#       "metadata": {
#         "uploaded_by": "admin@ailt.in",
#         "company_name": "AILT",
#         "uploaded_time": "2025-10-07T11:32:31.849000+00:00"
#       },
#       "created_at": "2025-10-07T11:32:31.553980Z"
#     },
#     {
#       "speaking_id": "f20dce96-746e-4539-9cee-03cb1d18c499",
#       "day_code": "day1",
#       "teaching_mode_id": "c7c4631e-8e22-40e8-9ee9-c48936bc799b",
#       "teaching_mode_code": "grammar",
#       "title": "BASIC",
#       "topic": "1.At the Railway Station\n2.The Importance of Reading Books\n3.Let\u2019s Talk About Your Favourite Sportsperson",
#       "context": " 1.(Talk about your train journey, tickets, and waiting for the platform.)\n 2.(Discuss why reading helps, what kind of books you like, and how you find time to read.)\n 3.(Focus on their great achievements, how hard they practice, and what you learn from them.)\n\n",
#       "difficulty_level": "beginner",
#       "metadata": {
#         "uploaded_by": "admin",
#         "company_name": "Iluzia Lab",
#         "updated_time": "2025-10-13T09:20:43.513154+00:00",
#         "uploaded_time": "2025-10-13T09:20:43.589000+00:00"
#       },
#       "created_at": "2025-10-07T11:31:57.851922Z"
#     }
#   ],
#   "count": 3
# }
# ================================================================================

# %% [markdown]
# ## 7. Session Management - LRG Sessions

# %%
# Start a Session
session_start_data = {
    "user_id": TEST_USER_ID,
    "modality": "reading",
    "day_code": "day1"
}

response = safe_api_call("POST", f"{BASE_URL}/sessions", headers=HEADERS, json=session_start_data)
if response:
    print_response("Start Session", response)
    if response.status_code == 201:
        test_data['session_id'] = response.json().get('session_id')
        print(f"{Colors.GREEN}Session ID saved: {test_data['session_id']}{Colors.RESET}")

# Submit Session (if we have a session_id)
if test_data['session_id']:
    session_submit_data = {
        "answers": [
            {
                "question_id": str(uuid4()),
                "user_answer": "High-level",
                "is_correct": True,
                "time_spent_sec": 15,
                "skill_tag": "comprehension"
            },
            {
                "question_id": str(uuid4()),
                "user_answer": "simplicity, readability",
                "is_correct": True,
                "time_spent_sec": 20,
                "skill_tag": "vocabulary"
            }
        ],
        "duration_sec": 35,
        "score_pct": 100.0
    }
    
    response = safe_api_call("POST", f"{BASE_URL}/sessions/{test_data['session_id']}/submit", 
                            headers=HEADERS, json=session_submit_data)
    if response:
        print_response("Submit Session", response)

# Get Session Details
if test_data['session_id']:
    response = safe_api_call("GET", f"{BASE_URL}/sessions/{test_data['session_id']}", headers=HEADERS)
    if response:
        print_response("Get Session Details", response)

# Get User Sessions List
response = safe_api_call("GET", f"{BASE_URL}/sessions?limit=5&offset=0", headers=HEADERS)
if response:
    print_response("Get User Sessions (Paginated)", response)
# Out:
# ================================================================================
# Get User Sessions (Paginated)
# Status: 200
#
# Response:
# {
#   "sessions": [],
#   "limit": 5,
#   "offset": 0,
#   "count": 0
# }
# ================================================================================

# %% [markdown]
# ## 8. Listening Evaluation Sessions

# %%
# Start Listening Session
listening_session_data = {
    "user_id": TEST_USER_ID,
    "day_code": "day1",
    "audio_url": "https://example.com/audio/day1.mp3"
}

response = safe_api_call("POST", f"{BASE_URL}/listening/sessions", headers=HEADERS, json=listening_session_data)
if response:
    print_response("Start Listening Session", response)
    if response.status_code == 201:
        test_data['listening_session_id'] = response.json().get('session_id')
        print(f"{Colors.GREEN}Listening Session ID saved: {test_data['listening_session_id']}{Colors.RESET}")

# Submit Listening Session
if test_data['listening_session_id']:
    listening_submit_data = {
        "answers": [
            {
                "question_id": str(uuid4()),
                "user_answer": "Paris",
                "is_correct": True,
                "time_spent_sec": 10,
                "skill_tag": "main_idea",
                "audio_replay_count": 2,
                "time_to_first_answer_sec": 5
            },
            {
                "question_id": str(uuid4()),
                "user_answer": "tomorrow",
                "is_correct": True,
                "time_spent_sec": 12,
                "skill_tag": "detail",
                "audio_replay_count": 1,
                "time_to_first_answer_sec": 8
            }
        ],
        "duration_sec": 45,
        "score_pct": 100.0,
        "xp_earned": 50,
        "audio_replay_count": 3,
        "completed_at": datetime.utcnow().isoformat() + "Z"
    }
    
    response = safe_api_call("POST", f"{BASE_URL}/listening/sessions/{test_data['listening_session_id']}/submit",
                            headers=HEADERS, json=listening_submit_data)
    if response:
        print_response("Submit Listening Session", response)

# Get Listening Session Details
if test_data['listening_session_id']:
    response = safe_api_call("GET", f"{BASE_URL}/listening/sessions/{test_data['listening_session_id']}",
                            headers=HEADERS)
    if response:
        print_response("Get Listening Session Details", response)

# Get Listening Session Mastery
if test_data['listening_session_id']:
    response = safe_api_call("GET", f"{BASE_URL}/listening/sessions/{test_data['listening_session_id']}/mastery",
                            headers=HEADERS)
    if response:
        print_response("Get Listening Session Mastery Breakdown", response)

# Get User Listening Progress
response = safe_api_call("GET", f"{BASE_URL}/listening/users/{TEST_USER_ID}/progress", headers=HEADERS)
if response:
    print_response("Get User Listening Progress", response)

# Get Listening Analytics
response = safe_api_call("GET", f"{BASE_URL}/listening/users/{TEST_USER_ID}/analytics", headers=HEADERS)
if response:
    print_response("Get Listening Analytics", response)
# Out:
# ================================================================================
# Get User Listening Progress
# Status: 200
#
# Response:
# {
#   "modality": "listening",
#   "date_range": "day1-latest",
#   "overall_mastery_pct": 0,
#   "total_sessions": 0,
#   "total_audio_replay_count": 0,
#   "skills": []
# }
# ================================================================================

# %% [markdown]
# ## 9. XP & Streaks

# %%
# Get User XP Summary
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/xp", headers=HEADERS)
if response:
    print_response("Get User XP Summary", response)

# Get Daily XP
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/xp/daily", headers=HEADERS)
if response:
    print_response("Get Daily XP Breakdown", response)

# Get User Level
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/level", headers=HEADERS)
if response:
    print_response("Get User Level Information", response)

# Get User Streak
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/streak", headers=HEADERS)
if response:
    print_response("Get User Streak Information", response)

# Get Daily Progress
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/daily-progress", headers=HEADERS)
if response:
    print_response("Get Daily Progress", response)

# Get Streak Calendar
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/streak-calendar", headers=HEADERS)
if response:
    print_response("Get Streak Calendar (Current Month)", response)

# Get Streak Calendar for Specific Month
current_month = datetime.now().strftime("%Y-%m")
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/streak-calendar?month={current_month}",
                        headers=HEADERS)
if response:
    print_response(f"Get Streak Calendar ({current_month})", response)
# Out:
# ================================================================================
# Get User XP Summary
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "total_xp": 0,
#   "today_xp": 0,
#   "current_level": 1,
#   "xp_to_next_level": 150,
#   "level_progress_pct": 0
# }
# ================================================================================
#
# ================================================================================
# Get Daily XP Breakdown
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "date": "2025-10-18",
#   "xp_earned_today": 0,
#   "xp_goal": 100,
#   "goal_completion_pct": 0,
#   "sessions_today": 0,
#   "breakdown": []
# }
# ================================================================================
#
# ================================================================================
# Get User Level Information
# Status: 200
#
# Response:
# {
#   "current_level": 1,
#   "level_name": "Beginner",
#   "total_xp": 0,
#   "xp_for_current_level": 0,
#   "xp_for_next_level": 150,
#   "xp_to_next_level": 150,
#   "progress_pct": 0
# }
# ================================================================================
#
# ================================================================================
# Get User Streak Information
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "current_streak": 0,
#   "longest_streak": 0,
#   "last_active_date": "2025-10-18",
#   "is_active_today": false,
#   "streak_status": "broken"
# }
# ================================================================================
#
# ================================================================================
# Get Daily Progress
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "date": "2025-10-18",
#   "xp_earned": 0,
#   "xp_goal": 100,
#   "sessions_completed": 0,
#   "session_goal": 3,
#   "time_spent_minutes": 0,
#   "modalities_completed": [],
#   "goals": [
#     {
#       "goal_type": "xp",
#       "target": 100,
#       "current": 0,
#       "is_completed": false
#     },
#     {
#       "goal_type": "sessions",
#       "target": 3,
#       "current": 0,
#       "is_completed": false
#     },
#     {
#       "goal_type": "perfect_day",
#       "target": 1,
#       "current": 0,
#       "is_completed": false
#     }
#   ],
#   "is_perfect_day": false
# }
# ================================================================================
#
# ================================================================================
# Get Streak Calendar (Current Month)
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "current_month": "2025-10",
#   "days": [
#     {
#       "date": "2025-10-01",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-02",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-03",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-04",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-05",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-06",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-07",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-08",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-09",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-10",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-11",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-12",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-13",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-14",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-15",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-16",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-17",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-18",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-19",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-20",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-21",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-22",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-23",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-24",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-25",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-26",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-27",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-28",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-29",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-30",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-31",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     }
#   ],
#   "current_streak": 0,
#   "perfect_days": 0
# }
# ================================================================================
#
# ================================================================================
# Get Streak Calendar (2025-10)
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "current_month": "2025-10",
#   "days": [
#     {
#       "date": "2025-10-01",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-02",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-03",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-04",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-05",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-06",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-07",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-08",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-09",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-10",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-11",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-12",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-13",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-14",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-15",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-16",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-17",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-18",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-19",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-20",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-21",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-22",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-23",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-24",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-25",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-26",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-27",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-28",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-29",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-30",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     },
#     {
#       "date": "2025-10-31",
#       "sessions_completed": 0,
#       "modalities_completed": [],
#       "total_xp_earned": 0,
#       "streak_day": 0
#     }
#   ],
#   "current_streak": 0,
#   "perfect_days": 0
# }
# ================================================================================

# %% [markdown]
# ## 10. Skill Mastery & Competencies

# %%
# Get Session Mastery (if we have a session)
if test_data['session_id']:
    response = safe_api_call("GET", f"{BASE_URL}/sessions/{test_data['session_id']}/mastery", headers=HEADERS)
    if response:
        print_response("Get Session Skill Mastery Breakdown", response)

# Get User Skill Progress for Reading
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/skills/progress?modality=reading",
                        headers=HEADERS)
if response:
    print_response("Get User Skill Progress - Reading", response)

# Get User Skill Progress for Listening
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/skills/progress?modality=listening",
                        headers=HEADERS)
if response:
    print_response("Get User Skill Progress - Listening", response)

# Get User Skill Progress for Grammar
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/skills/progress?modality=grammar",
                        headers=HEADERS)
if response:
    print_response("Get User Skill Progress - Grammar", response)

# Get Mastery Overview (All Modalities)
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/mastery-overview", headers=HEADERS)
if response:
    print_response("Get Complete Mastery Overview", response)

# Get Competencies by Day
response = safe_api_call("GET", f"{BASE_URL}/users/{TEST_USER_ID}/competencies/reading/day/day1",
                        headers=HEADERS)
if response:
    print_response("Get Competencies - Reading Day 1", response)
# Out:
# ================================================================================
# Get User Skill Progress - Reading
# Status: 200
#
# Response:
# {
#   "modality": "reading",
#   "date_range": "day1-latest",
#   "skills": []
# }
# ================================================================================
#
# ================================================================================
# Get User Skill Progress - Listening
# Status: 200
#
# Response:
# {
#   "modality": "listening",
#   "date_range": "day1-latest",
#   "skills": []
# }
# ================================================================================
#
# ================================================================================
# Get User Skill Progress - Grammar
# Status: 200
#
# Response:
# {
#   "modality": "grammar",
#   "date_range": "day1-latest",
#   "skills": []
# }
# ================================================================================
#
# ================================================================================
# Get Complete Mastery Overview
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "listening": {
#     "overall_mastery_pct": 0,
#     "skills": {}
#   },
#   "reading": {
#     "overall_mastery_pct": 0,
#     "skills": {}
#   },
#   "grammar": {
#     "overall_mastery_pct": 0,
#     "skills": {}
#   }
# }
# ================================================================================
#
# ================================================================================
# Get Competencies - Reading Day 1
# Status: 200
#
# Response:
# {
#   "modality": "reading",
#   "date_range": "day1",
#   "skills": []
# }
# ================================================================================

# %% [markdown]
# ## 11. Dashboard Analytics

# %%
# Get Dashboard Summary (7 days)
response = safe_api_call("GET", f"{BASE_URL}/dashboard/summary?window=7d", headers=HEADERS)
if response:
    print_response("Dashboard Summary - 7 Days", response)

# Get Dashboard Summary (30 days)
response = safe_api_call("GET", f"{BASE_URL}/dashboard/summary?window=30d", headers=HEADERS)
if response:
    print_response("Dashboard Summary - 30 Days", response)

# Get Dashboard Summary (90 days)
response = safe_api_call("GET", f"{BASE_URL}/dashboard/summary?window=90d", headers=HEADERS)
if response:
    print_response("Dashboard Summary - 90 Days", response)

# Get Modality Detail - Listening
response = safe_api_call("GET", f"{BASE_URL}/dashboard/detail/listening", headers=HEADERS)
if response:
    print_response("Modality Detail - Listening", response)

# Get Modality Detail - Reading
response = safe_api_call("GET", f"{BASE_URL}/dashboard/detail/reading", headers=HEADERS)
if response:
    print_response("Modality Detail - Reading", response)

# Get Modality Detail - Grammar
response = safe_api_call("GET", f"{BASE_URL}/dashboard/detail/grammar", headers=HEADERS)
if response:
    print_response("Modality Detail - Grammar", response)

# Get User Progress
response = safe_api_call("GET", f"{BASE_URL}/dashboard/progress", headers=HEADERS)
if response:
    print_response("User Overall Progress", response)
# Out:
# ================================================================================
# Dashboard Summary - 7 Days
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "as_of": "2025-10-18T12:45:50.380868",
#   "streak_days": 0,
#   "xp": {
#     "total": 0,
#     "today": 0
#   },
#   "daily_target": {
#     "target": 3,
#     "completed": 0
#   },
#   "last_activity": null,
#   "weekly_minutes": [
#     {
#       "date": "2025-10-11",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-12",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-13",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-14",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-15",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-16",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-17",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-18",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     }
#   ],
#   "accuracy_trend": {
#     "listening": [],
#     "reading": [],
#     "grammar": []
#   },
#   "completion_heatmap": [
#     {
#       "date": "2025-10-11",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-12",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-13",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-14",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-15",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-16",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-17",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-18",
#       "L": false,
#       "R": false,
#       "G": false
#     }
#   ],
#   "recent_results": [],
#   "badges": [],
#   "next_reward": {
#     "type": "streak",
#     "target": 3,
#     "current": 0
#   }
# }
# ================================================================================
#
# ================================================================================
# Dashboard Summary - 30 Days
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "as_of": "2025-10-18T12:45:53.442109",
#   "streak_days": 0,
#   "xp": {
#     "total": 0,
#     "today": 0
#   },
#   "daily_target": {
#     "target": 3,
#     "completed": 0
#   },
#   "last_activity": null,
#   "weekly_minutes": [
#     {
#       "date": "2025-09-18",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-19",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-20",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-21",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-22",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-23",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-24",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-25",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-26",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-27",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-28",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-29",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-30",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-01",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-02",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-03",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-04",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-05",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-06",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-07",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-08",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-09",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-10",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-11",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-12",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-13",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-14",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-15",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-16",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-17",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-18",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     }
#   ],
#   "accuracy_trend": {
#     "listening": [],
#     "reading": [],
#     "grammar": []
#   },
#   "completion_heatmap": [
#     {
#       "date": "2025-09-18",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-19",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-20",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-21",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-22",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-23",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-24",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-25",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-26",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-27",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-28",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-29",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-30",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-01",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-02",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-03",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-04",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-05",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-06",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-07",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-08",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-09",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-10",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-11",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-12",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-13",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-14",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-15",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-16",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-17",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-18",
#       "L": false,
#       "R": false,
#       "G": false
#     }
#   ],
#   "recent_results": [],
#   "badges": [],
#   "next_reward": {
#     "type": "streak",
#     "target": 3,
#     "current": 0
#   }
# }
# ================================================================================
#
# ================================================================================
# Dashboard Summary - 90 Days
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "as_of": "2025-10-18T12:45:56.253639",
#   "streak_days": 0,
#   "xp": {
#     "total": 0,
#     "today": 0
#   },
#   "daily_target": {
#     "target": 3,
#     "completed": 0
#   },
#   "last_activity": null,
#   "weekly_minutes": [
#     {
#       "date": "2025-07-20",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-21",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-22",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-23",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-24",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-25",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-26",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-27",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-28",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-29",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-30",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-07-31",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-01",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-02",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-03",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-04",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-05",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-06",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-07",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-08",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-09",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-10",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-11",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-12",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-13",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-14",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-15",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-16",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-17",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-18",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-19",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-20",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-21",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-22",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-23",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-24",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-25",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-26",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-27",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-28",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-29",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-30",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-08-31",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-01",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-02",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-03",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-04",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-05",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-06",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-07",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-08",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-09",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-10",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-11",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-12",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-13",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-14",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-15",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-16",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-17",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-18",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-19",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-20",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-21",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-22",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-23",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-24",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-25",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-26",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-27",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-28",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-29",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-09-30",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-01",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-02",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-03",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-04",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-05",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-06",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-07",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-08",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-09",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-10",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-11",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-12",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-13",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-14",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-15",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-16",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-17",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     },
#     {
#       "date": "2025-10-18",
#       "listening_min": 0,
#       "reading_min": 0,
#       "grammar_min": 0
#     }
#   ],
#   "accuracy_trend": {
#     "listening": [],
#     "reading": [],
#     "grammar": []
#   },
#   "completion_heatmap": [
#     {
#       "date": "2025-07-20",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-21",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-22",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-23",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-24",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-25",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-26",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-27",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-28",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-29",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-30",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-07-31",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-01",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-02",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-03",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-04",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-05",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-06",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-07",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-08",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-09",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-10",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-11",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-12",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-13",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-14",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-15",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-16",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-17",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-18",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-19",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-20",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-21",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-22",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-23",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-24",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-25",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-26",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-27",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-28",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-29",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-30",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-08-31",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-01",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-02",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-03",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-04",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-05",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-06",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-07",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-08",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-09",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-10",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-11",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-12",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-13",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-14",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-15",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-16",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-17",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-18",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-19",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-20",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-21",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-22",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-23",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-24",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-25",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-26",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-27",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-28",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-29",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-09-30",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-01",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-02",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-03",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-04",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-05",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-06",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-07",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-08",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-09",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-10",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-11",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-12",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-13",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-14",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-15",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-16",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-17",
#       "L": false,
#       "R": false,
#       "G": false
#     },
#     {
#       "date": "2025-10-18",
#       "L": false,
#       "R": false,
#       "G": false
#     }
#   ],
#   "recent_results": [],
#   "badges": [],
#   "next_reward": {
#     "type": "streak",
#     "target": 3,
#     "current": 0
#   }
# }
# ================================================================================
#
# ================================================================================
# Modality Detail - Listening
# Status: 200
#
# Response:
# {
#   "modality": "listening",
#   "accuracy_by_day": [],
#   "minutes_by_day": [],
#   "question_breakdown": [],
#   "best_day": null,
#   "best_accuracy": 0.0,
#   "total_time_minutes": 0,
#   "total_questions": 0,
#   "last_session": null
# }
# ================================================================================
#
# ================================================================================
# Modality Detail - Reading
# Status: 200
#
# Response:
# {
#   "modality": "reading",
#   "accuracy_by_day": [],
#   "minutes_by_day": [],
#   "question_breakdown": [],
#   "best_day": null,
#   "best_accuracy": 0.0,
#   "total_time_minutes": 0,
#   "total_questions": 0,
#   "last_session": null
# }
# ================================================================================
#
# ================================================================================
# Modality Detail - Grammar
# Status: 200
#
# Response:
# {
#   "modality": "grammar",
#   "accuracy_by_day": [],
#   "minutes_by_day": [],
#   "question_breakdown": [],
#   "best_day": null,
#   "best_accuracy": 0.0,
#   "total_time_minutes": 0,
#   "total_questions": 0,
#   "last_session": null
# }
# ================================================================================
#
# ================================================================================
# User Overall Progress
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "total_xp": 0,
#   "current_streak": 0,
#   "badges_earned": 0,
#   "total_sessions": 0,
#   "last_activity": null
# }
# ================================================================================

# %% [markdown]
# ## 12. Unified Analytics

# %%
# Get Unified Stats
response = safe_api_call("GET", f"{BASE_URL}/unified/stats", headers=HEADERS)
if response:
    print_response("Unified Stats - All Activities", response)

# Get Unified Dashboard (7 days)
response = safe_api_call("GET", f"{BASE_URL}/unified/dashboard?days=7", headers=HEADERS)
if response:
    print_response("Unified Dashboard - 7 Days", response)

# Get Unified Dashboard (30 days)
response = safe_api_call("GET", f"{BASE_URL}/unified/dashboard?days=30", headers=HEADERS)
if response:
    print_response("Unified Dashboard - 30 Days", response)

# Get Activity Timeline
response = safe_api_call("GET", f"{BASE_URL}/unified/timeline?limit=10&offset=0", headers=HEADERS)
if response:
    print_response("Activity Timeline - Recent 10", response)

# Get Comprehensive Progress - Weekly
response = safe_api_call("GET", f"{BASE_URL}/unified/progress?period=weekly", headers=HEADERS)
if response:
    print_response("Comprehensive Progress - Weekly", response)

# Get Comprehensive Progress - Monthly
response = safe_api_call("GET", f"{BASE_URL}/unified/progress?period=monthly", headers=HEADERS)
if response:
    print_response("Comprehensive Progress - Monthly", response)

# Get Comprehensive Progress - All Time
response = safe_api_call("GET", f"{BASE_URL}/unified/progress?period=all_time", headers=HEADERS)
if response:
    print_response("Comprehensive Progress - All Time", response)

# Get Week Comparison
response = safe_api_call("GET", f"{BASE_URL}/unified/comparison", headers=HEADERS)
if response:
    print_response("Week-over-Week Comparison", response)

# Get Achievements Summary
response = safe_api_call("GET", f"{BASE_URL}/unified/achievements", headers=HEADERS)
if response:
    print_response("Achievements Summary", response)

# Get Learning Insights
response = safe_api_call("GET", f"{BASE_URL}/unified/insights", headers=HEADERS)
if response:
    print_response("Learning Insights & Recommendations", response)
# Out:
# ================================================================================
# Unified Stats - All Activities
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "display_name": null,
#   "email": null,
#   "skill_level": null,
#   "target_language": null,
#   "lrg_sessions": 0,
#   "lrg_time_sec": 0,
#   "lrg_avg_score": null,
#   "writing_evaluations": 0,
#   "writing_avg_score": null,
#   "speaking_sessions": 0,
#   "current_streak": 0,
#   "longest_streak": 0,
#   "total_xp": 0,
#   "last_activity": null
# }
# ================================================================================
#
# ================================================================================
# Unified Dashboard - 7 Days
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "as_of": "2025-10-18T12:46:09.740654",
#   "period_days": 7,
#   "total_activities": 0,
#   "total_time_minutes": 0,
#   "current_streak": 0,
#   "total_xp": 0,
#   "lrg_stats": {
#     "session_count": 0,
#     "total_time_sec": 0,
#     "avg_score": null,
#     "by_modality": {
#       "reading": 0,
#       "listening": 0,
#       "grammar": 0
#     }
#   },
#   "writing_stats": {
#     "evaluation_count": 0,
#     "avg_score": null,
#     "total_time_sec": 0,
#     "recent_feedback": []
#   },
#   "speaking_stats": {
#     "session_count": 0,
#     "total_time_sec": 0,
#     "languages": []
#   },
#   "recent_activities": [],
#   "badges": [],
#   "next_milestone": {
#     "type": "streak",
#     "target": 3,
#     "current": 0
#   }
# }
# ================================================================================
#
# ================================================================================
# Unified Dashboard - 30 Days
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "as_of": "2025-10-18T12:46:11.867878",
#   "period_days": 30,
#   "total_activities": 0,
#   "total_time_minutes": 0,
#   "current_streak": 0,
#   "total_xp": 0,
#   "lrg_stats": {
#     "session_count": 0,
#     "total_time_sec": 0,
#     "avg_score": null,
#     "by_modality": {
#       "reading": 0,
#       "listening": 0,
#       "grammar": 0
#     }
#   },
#   "writing_stats": {
#     "evaluation_count": 0,
#     "avg_score": null,
#     "total_time_sec": 0,
#     "recent_feedback": []
#   },
#   "speaking_stats": {
#     "session_count": 0,
#     "total_time_sec": 0,
#     "languages": []
#   },
#   "recent_activities": [],
#   "badges": [],
#   "next_milestone": {
#     "type": "streak",
#     "target": 3,
#     "current": 0
#   }
# }
# ================================================================================
#
# ================================================================================
# Activity Timeline - Recent 10
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "items": [],
#   "total_count": 0,
#   "page": 1,
#   "page_size": 10
# }
# ================================================================================
#
# ================================================================================
# Comprehensive Progress - Weekly
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "report_period": "weekly",
#   "total_time_minutes": 0,
#   "avg_session_minutes": 0.0,
#   "total_lrg_sessions": 0,
#   "total_writing_submissions": 0,
#   "total_speaking_sessions": 0,
#   "lrg_avg_accuracy": null,
#   "writing_avg_score": null,
#   "speaking_evaluation_avg": null,
#   "active_days": 0,
#   "current_streak": 0,
#   "consistency_score": 0.0,
#   "total_xp": 0,
#   "badges_earned": 0,
#   "concepts_mastered": 0,
#   "improvements": [],
#   "areas_for_focus": [
#     "Build daily practice habit",
#     "Try writing practice"
#   ]
# }
# ================================================================================
#
# ================================================================================
# Comprehensive Progress - Monthly
# Status: 200
#
# Response:
# {
#   "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#   "report_period": "monthly",
#   "total_time_minutes": 0,
#   "avg_session_minutes": 0.0,
#   "total_lrg_sessions": 0,
#   "total_writing_submissions": 0,
#   "total_speaking_sessions": 0,
#   "lrg_avg_accuracy": null,
#   "writing_avg_score": null,
#   "speaking_evaluation_avg": null,
#   "active_days": 0,
#   "current_streak": 0,
#   "consistency_score": 0.0,
#   "total_xp": 0,
#   "badges_earned": 0,
#   "concepts_mastered": 0,
#   "improvements": [],
#   "areas_for_focus": [
#     "Build daily practice habit",
#     "Try writing practice"
#   ]
# }
# ================================================================================
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# ================================================================================
# Week-over-Week Comparison
# Status: 200
#
# Response:
# {
#   "current_week": {
#     "user_id": "87f27677-c00e-43d8-abc1-9ee77ef508e5",
#     "report_period": "weekly",
#     "total_time_minutes": 0,
#     "avg_session_minutes": 0.0,
#     "total_lrg_sessions": 0,
#     "total_writing_submissions": 0,
#     "total_speaking_sessions": 0,
#     "lrg_avg_accuracy": null,
#     "writing_avg_score": null,
#     "speaking_evaluation_avg": null,
#     "active_days": 0,
#     "current_streak": 0,
#     "consistency_score": 0.0,
#     "total_xp": 0,
#     "badges_earned": 0,
#     "concepts_mastered": 0,
#     "improvements": [],
#     "areas_for_focus": [
#       "Build daily practice habit",
#       "Try writing practice"
#     ]
#   },
#   "previous_week": {},
#   "changes": {
#     "total_activities": 0,
#     "total_time_minutes": 0,
#     "avg_score": 0
#   }
# }
# ================================================================================
#
# ================================================================================
# Achievements Summary
# Status: 200
#
# Response:
# {
#   "badges": {
#     "earned": 0,
#     "recent": [],
#     "categories": {
#       "streaks": 0,
#       "performance": 0,
#       "volume": 0
#     }
#   },
#   "streaks": {
#     "current": 0,
#     "longest": 0,
#     "at_risk": false
#   },
#   "xp": {
#     "total": 0,
#     "rank": "Bronze",
#     "next_rank_at": 1000
#   },
#   "milestones": {
#     "total_activities": 0,
#     "total_time_hours": 0,
#     "languages_practiced": 1
#   }
# }
# ================================================================================
#
# ================================================================================
# Learning Insights & Recommendations
# Status: 200
#
# Response:
# {
#   "strengths": [],
#   "improvements": [],
#   "focus_areas": [
#     "Build daily practice habit",
#     "Try writing practice"
#   ],
#   "recommendations": [
#     {
#       "type": "consistency",
#       "message": "Try to practice daily for better retention",
#       "priority": "high"
#     },
#     {
#       "type": "variety",
#       "message": "Try writing practice to complement your learning",
#       "priority": "low"
#     }
#   ],
#   "trends": {
#     "consistency": {
#       "score": 0.0,
#       "trend": "stable"
#     },
#     "performance": {
#       "lrg": null,
#       "writing": null,
#       "overall_trend": "improving"
#     }
#   }
# }
# ================================================================================

# %% [markdown]
# ## 13. Cleanup (Optional)

# %%
# Delete created test data (optional - uncomment to use)

# Delete Reading
# if test_data['reading_id']:
#     response = safe_api_call("DELETE", f"{BASE_URL}/reading/{test_data['reading_id']}", headers=HEADERS)
#     if response and response.status_code == 204:
#         print(f"{Colors.GREEN}Reading deleted successfully{Colors.RESET}")

# Delete Grammar
# if test_data['grammar_id']:
#     response = safe_api_call("DELETE", f"{BASE_URL}/grammar/{test_data['grammar_id']}", headers=HEADERS)
#     if response and response.status_code == 204:
#         print(f"{Colors.GREEN}Grammar deleted successfully{Colors.RESET}")

# Delete Writing
# if test_data['writing_id']:
#     response = safe_api_call("DELETE", f"{BASE_URL}/writing/{test_data['writing_id']}", headers=HEADERS)
#     if response and response.status_code == 204:
#         print(f"{Colors.GREEN}Writing deleted successfully{Colors.RESET}")

# Delete Speaking
# if test_data['speaking_id']:
#     response = safe_api_call("DELETE", f"{BASE_URL}/speaking/{test_data['speaking_id']}", headers=HEADERS)
#     if response and response.status_code == 204:
#         print(f"{Colors.GREEN}Speaking deleted successfully{Colors.RESET}")

print(f"{Colors.BLUE}Cleanup section (commented out by default){Colors.RESET}")
print(f"Uncomment delete operations if you want to clean up test data")

# %% [markdown]
# ## 14. Test Summary

# %%
# Print test summary
print(f"\n{Colors.BLUE}{'='*80}{Colors.RESET}")
print(f"{Colors.GREEN}API TESTING COMPLETE{Colors.RESET}")
print(f"{Colors.BLUE}{'='*80}{Colors.RESET}\n")

print(f"{Colors.YELLOW}Test Data Created:{Colors.RESET}")
for key, value in test_data.items():
    status = Colors.GREEN + "✓" if value else Colors.RED + "✗"
    print(f"{status} {key}: {value if value else 'Not created'}{Colors.RESET}")

print(f"\n{Colors.YELLOW}Tested Endpoints:{Colors.RESET}")
endpoint_categories = [
    "Health & Meta (3 endpoints)",
    "Reading Content (5 endpoints)",
    "Listening Content (5 endpoints)",
    "Grammar Content (4 endpoints)",
    "Writing Content (4 endpoints)",
    "Speaking Content (4 endpoints)",
    "LRG Sessions (4 endpoints)",
    "Listening Sessions (5 endpoints)",
    "XP & Streaks (7 endpoints)",
    "Skill Mastery (6 endpoints)",
    "Dashboard Analytics (7 endpoints)",
    "Unified Analytics (9 endpoints)"
]

for category in endpoint_categories:
    print(f"{Colors.GREEN}✓{Colors.RESET} {category}")

print(f"\n{Colors.GREEN}All API tests completed successfully!{Colors.RESET}")
print(f"{Colors.BLUE}{'='*80}{Colors.RESET}")
# Out:
# ================================================================================
# API TESTING COMPLETE
# ================================================================================
#
# Test Data Created:
# ✗ reading_id: Not created
# ✗ listening_id: Not created
# ✗ grammar_id: Not created
# ✗ writing_id: Not created
# ✗ speaking_id: Not created
# ✗ session_id: Not created
# ✗ listening_session_id: Not created
#
# Tested Endpoints:
# ✓ Health & Meta (3 endpoints)
# ✓ Reading Content (5 endpoints)
# ✓ Listening Content (5 endpoints)
# ✓ Grammar Content (4 endpoints)
# ✓ Writing Content (4 endpoints)
# ✓ Speaking Content (4 endpoints)
# ✓ LRG Sessions (4 endpoints)
# ✓ Listening Sessions (5 endpoints)
# ✓ XP & Streaks (7 endpoints)
# ✓ Skill Mastery (6 endpoints)
# ✓ Dashboard Analytics (7 endpoints)
# ✓ Unified Analytics (9 endpoints)
#
# All API tests completed successfully!
# ================================================================================
